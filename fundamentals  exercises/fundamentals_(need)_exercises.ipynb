# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need) Exercises</span></div>

# %% [markdown]
# # Exercise 1

# %% [markdown]
# Purely from memory, list as many of the basic Python features I mentioned in my notes as you remember.
# Use a Markdown cell for this list.
#
# 1. Python is interpreted.
# 2. Python is case-sensitive.
# 3. Python has functions.
# 4. There are comments in Python.
#
# Now, visit the notes and complete the list with the ones you missed.
# Indicate those you missed by putting them in italics.

# %% [markdown]
# # Exercise 2

# %%
from math import sqrt
x, y = 3, 4
z = sqrt(x*2 + y**2)
print(x, y, z)
# Out:
# 3 4 4.69041575982343

# %% [markdown]
# # Exercise 3

# %% [markdown]
# | # | Term | Description |
# | --- | --- | --- |
# | 1 | Function | Subroutine; A sequence of program instructions that performs a specific task, packaged as a unit |
# | 2 | Arguments | Parameters passed into functions. E.g. x in f(x) |
# | 3 | Comments | A chunk of text describing a piece of code or displaying important information. Not parsed by the interpreter. |
# | 4 | Indentations | A way for Python to differentiate different scopes instead of using braces. |
# | 5 | Packages | A "library" of functions and classes that can be installed and imported. |
# | 6 | . | A way to denote ownership (e.g. attribute/property, member functions) |
# | 7 | : | Used in dictionaries and scoping |
# | 8 | [] | An empty list. |
# | 9 | [[[]]] | A list of list containing an empty list. |
# | 10 | {} | An empty dictionary. |

# %% [markdown]
# # Exercise 4

# %%
# Division
5/2
# Out:
# 2.5

# %%
# Integer division
5//2
# Out:
# 2

# %%
# Modulo operator
5%2
# Out:
# 1
