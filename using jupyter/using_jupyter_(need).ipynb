# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need)</span></div>

# %% [markdown]
# # 1 What to expect in this chapter

# %% [markdown]
# Jupyter works so that you can ask it to do something, and it immediately shows you the result.

# %% [markdown]
# In fact, the older name for Jupyter Notebooks was ‘IPython notebooks’, meaning ‘interactive Python notebooks’.

# %% [markdown]
# # 2 Getting ready

# %% [markdown]
# Use the terminal to navigate to the folder Using Jupyter in your Learning Portfolio.
#
# Start Jupyter notebooks through the terminal. Please refer to the previous chapter if you have forgotten how to do this.
#
# Use the button New to create a new Python 3 (ipykernel) notebook.
#
# Click the Untitled at the top (next to the Jupiter logo) and rename the file to using-jupyter_need.

# %% [markdown]
# # 3 Getting started with Jupyter

# %% [markdown]
# ## 3.1 It is all about running cells

# %% [markdown]
# The basic unit of a Jupyter Notebook is a cell. A cell can either accept Python code or text in a format called Markdown.
#
# A cell ready to accept Python is called a code cell, while one ready for Markdown is called a Markdown cell. To ‘get things done’, we Run a cell by using the Run button or the keyboard shortcut CTRL + ENTER (or CMD + ENTER).
#
# Running a code cell invokes Python while running a Markdown cell renders (i.e., makes it look pretty) your Markdown text. You will see how all this works in a bit, so don’t worry if things sound a tad cryptic at the moment.

# %% [markdown]
# ## 3.2 A traditional start

# %%
print("Hello World!")

# %% [markdown]
# # 4 All about Markdown

# %% [markdown]
# ## 4.1 Rendering Markdown cells

# %% [markdown]
# The ships hung in the sky in much the same way that bricks don’t.

# %% [markdown]
# ## 4.2 Some basic syntax

# %% [markdown]
# The ships *hung in the sky* in much the same way that **bricks don’t.**<sup>1</sup><sub>QUOTE</sub>

# %% [markdown]
# ## 4.3 Headings

# %% [markdown]
# # The largest heading
#
# ## The second-largest heading
#
# ### The third-largest heading
#
# #### The smallest heading

# %% [markdown]
# ## 4.4 Displaying Code

# %% [markdown]
# ```python
# print('Hello World!')
# ```

# %% [markdown]
# ## 4.5 Links

# %% [markdown]
# [SP2273 Website](https://sps.nus.edu.sg/sp2273)

# %% [markdown]
# ## 4.6 Images

# %% [markdown]
# ![](https://nus.edu.sg/images/default-source/base/logo.png)

# %% [markdown]
# ## 4.7 Tables

# %% [markdown]
# | A    |  B   |    C |
# | :--- | :--: | ---: |
# | a1   |  b1  |   c1 |
# | a2   |  b2  |   c2 |
# | a3   |  b3  |   c3 |

# %% [markdown]
# ## 4.8 Lists

# %% [markdown]
# 1. Master Yoda
# 1. Luke Skywalker
# 1. Anakin Skywalker

# %% [markdown]
# - Master Yoda
# - Luke Skywalker
# - Anakin Skywalker

# %% [markdown]
# 1. Master Yoda
#    1. Was a Jedi
#    1. Was a bit green
# 1. Luke Skywalker
#    1. Was a Jedi
#    1. Is Anakin's son.
# 1. Anakin Skywalker
#    1. Was a Jedi then became a baddie
#    1. Is famous for saying 'Luke, I am your father'

# %% [markdown]
# 1. Master Yoda
#    - Was a Jedi
#    - Was a bit green
# 1. Luke Skywalker
#    - Was a Jedi
#    - Is Anakin's son.
# 1. Anakin Skywalker
#    - Was a Jedi then, became a baddie
#    - Is famous for saying, _'Luke, I am your father'_.

# %% [markdown]
# ## 4.9 Equations

# %% [markdown]
# $\sqrt{b^2-4ac}$

# %% [markdown]
# $$
# x = \dfrac{-b \pm \sqrt{b^2-4ac}}{2a}
# $$

# %% [markdown]
# ## Footnotes

# %% [markdown]
# 1. You and I will have problems if you do not know about The Hitchhiker’s Guide to the Galaxy.↩︎
# 2. that you are using Windows.↩︎
# 3. especially with doubly annoying software like Word↩︎
# 4. Using a engine called MathJax↩︎
