# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Some tips and tricks

# %% [markdown]
# ## 1.1 Keyboard Shortcuts

# %% [markdown]
# Shortcuts I didn't know:
# | Action | Shortcut |
# | --- | :-: |
# | Merge cells | `SHIFT + M` |
# | Show shortcuts | `ESC + H` |

# %% [markdown]
# ### Things to note

# %% [markdown]
# - You can select one or more cells using `SHIFT` and the up and down arrow keys.
# - Be careful with the delete shortcut; it can be ruthless.
# - You can view (and set) shortcuts for Jupyter Notebooks by typing `ESC + H`.

# %% [markdown]
# ## 1.2 Shell commands

# %%
# !cd # BAD
# %pwd
# Out:
# c:\Users\DELL\Desktop\learning-portfolio-SamuelFoo\using jupyter

# %%
# !dir # BAD
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is E8E7-0345
#
#  Directory of c:\Users\DELL\Desktop\learning-portfolio-SamuelFoo\using jupyter
#
# 17/01/2024  08:54 am    <DIR>          .
# 22/01/2024  09:26 am    <DIR>          ..
# 20/02/2024  12:41 am             3,571 using_jupyter_(good).ipynb
# 19/02/2024  12:39 am             6,777 using_jupyter_(need).ipynb
#                2 File(s)         10,348 bytes
#                2 Dir(s)  189,830,389,760 bytes free

# %% [markdown]
# # 3 Shell Magic

# %%
# %timeit x=10
# Out:
# 10.4 ns ± 0.15 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)

# %%
# %%timeit 
x=10
y=10
z=10
# Out:
# 17.3 ns ± 0.394 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)

# %% [markdown]
# # 4 The Kernel

# %% [markdown]
# - All the behind-the-scenes work of running a Jupyter Notebook is done by a sub-routine called the _Kernel_.
# - You can interrupt, restart, or shut down the kernel using the `Kernel` button in the toolbar. As you start coding with Python, you will need to do these because Jupyter sometimes misbehaves, and you can make blunders that require a reset.
